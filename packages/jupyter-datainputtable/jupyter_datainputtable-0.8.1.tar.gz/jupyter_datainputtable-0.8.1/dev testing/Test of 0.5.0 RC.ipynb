# %%
from input_table import *
# Out:
# <script type="text/javascript">//Javascript for input_table to use in Jupyter notebook
# //Jonathan Gutow <gutow@uwosh.edu> March 24, 2019
# //license GPL V3 or greater.
#
# //Get input table dimensions and build
# function get_table_dim(){
#     Jupyter.notebook.insert_cell_below();
#     Jupyter.notebook.select_next(true);
#     Jupyter.notebook.focus_cell();
#     var currentcell = Jupyter.notebook.get_selected_cell();
#     var htmlstr =`
#     <div id="input_table_dim_dlg" style="border:thick;border-color:red;border-style:solid;">
#       <div>Set table size remembering to include enough rows and columns for labels.</div>
#       <table id="init_input_table_dim"><tr>
#         <td> Rows:</td><td><input id="init_row_dim" type="text" size="7" value="2"
#           onblur="record_input(this)"></input></td>
#         <td>Columns:</td><td><input id="init_col_dim" type="text" size="7" value="2"
#           onblur="record_input(this)"></input></td>
# ...

# %%
help("input_table")
# Out:
# Help on package input_table:
#
# NAME
#     input_table
#
# PACKAGE CONTENTS
#
#
# FUNCTIONS
#     create_input_table()
#         This function calls the javascript function `get_table_dim()` to start building a data input table
#         that will be created in the output area of a Jupyter cell. Because the tools are
#         meant to be used with direct calls to javascript from a html/javascript menu, when you call this python
#         function it will add an extra blank cell before the cell in which the table is created. This does
#         not occur when doing things in javascript.
#
# DATA
#     mydir = '/home/jonathan/GIT/jupyter-datainputtable/input_table'
#     name = 'input_table'
#     tempJSfile = <_io.TextIOWrapper name='/home/jonathan/GIT/jupy...script...
#     tempscript = '<script type="text/javascript">//Javascript for ...\';\n...
#
# FILE
#     /home/jonathan/GIT/jupyter-datainputtable/input_table/__init__.py

# %%
create_input_table()

# %%
# If no data table appears in the output of this cell, run the cell to display the table.
try:
    from input_table import *
except (ImportError, FileNotFoundError) as e:
    from IPython.display import HTML
    print("Table editing will not work because `jupyter_datainputtable` module is not installed in python kernel")
display(HTML('<table class="input_table" id="it_1584930401208"><tbody> <tr class="input_table r0">  <td class="input_table r0 c0"><button class="edit_btn" onclick="edit_input_table(\'it_1584930401208\');">Edit Data</button></td><td class="input_table r0 c1"><span class="table_label">A</span></td> </tr> <tr class="input_table r1"><td class="input_table r1 c0"><span class="table_label">0</span></td>  <td class="input_table r1 c1"><span class="data_cell">one element</span></td> </tr></tbody></table>'))
# Out:
# <table class="input_table" id="it_1584930401208"><tbody> <tr class="input_table r0">  <td class="input_table r0 c0"><button class="lock_btn" onclick="lock_labels('it_1584930401208')">Lock Column and Row Labels</button></td><td class="input_table r0 c1"><input class="table_label" type="text" size="15" value="Col_0" style="font-weight:bold;" onblur="record_input(this)"></input></td> </tr> <tr class="input_table r1"><td class="input_table r1 c0"><input class="table_label" type="text" size="7" value="0" style="font-weight:bold;" onblur="record_input(this)"></input></td>  <td class="input_table r1 c1"><input class="data_cell" type="text" size="7" onblur="record_input(this)"></input></td> </tr></tbody></table>
