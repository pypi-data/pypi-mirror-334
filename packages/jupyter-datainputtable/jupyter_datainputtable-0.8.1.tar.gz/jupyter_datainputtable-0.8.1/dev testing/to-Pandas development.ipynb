# %%
from input_table import *
# Out:
# <script type="text/javascript">//Javascript for input_table to use in Jupyter notebook
# //Jonathan Gutow <gutow@uwosh.edu> March 24, 2019
# //license GPL V3 or greater.
#
# //Get input table dimensions and build
# function get_table_dim(){
#     Jupyter.notebook.insert_cell_below();
#     Jupyter.notebook.select_next(true);
#     Jupyter.notebook.focus_cell();
#     var currentcell = Jupyter.notebook.get_selected_cell();
#     var htmlstr =`
#     <div id="input_table_dim_dlg" style="border:thick;border-color:red;border-style:solid;">
#       <div>Set table size remembering to include enough rows and columns for labels.</div>
#       <table id="init_input_table_dim"><tr>
#         <td> Rows:</td><td><input id="init_row_dim" type="text" size="7" value="2"
#           onblur="record_input(this)"></input></td>
#         <td>Columns:</td><td><input id="init_col_dim" type="text" size="7" value="2"
#           onblur="record_input(this)"></input></td>
# ...

# %%
create_input_table()

# %%
# %%javascript
#
# var table_data_to_named_DF = '('+function (){
#      var dialog = document.getElementById("DFName_dia");
#      var inputs = dialog.querySelectorAll('input');
#      var values = [];
#      for (var i=0;i<inputs.length;i++){
#          values[i]=inputs[i].value;
#      }
#      info = dialog.querySelectorAll('#post_pr_info')[0].innerHTML;
#      dialog.remove();
#  //    <code to use the items in values and post_pr_info> //order of items is
#  //    the same as the fields list.
#     var parentTable = document.getElementById(info);
#     var rows = parentTable.querySelectorAll('tr');
#     var nrows = rows.length;
#     var ncols = rows[0].querySelectorAll('td').length;
#     var colnames = [];
#     var escnamestr = []
#     var data = [];
#     //sort data into columns
#     for(var i=1;i<ncols;i++){
#         var classstr='.c'+i
#         colnames[i-1]=rows[0].querySelectorAll(classstr)[0].querySelectorAll(".table_label")[0].innerHTML;
#         escnamestr[i-1] = colnames[i-1].replace(' ','_').replace('(','_').replace(')','_').replace('/','_').replace('*','_');
#         var tempcol =[];
#         for (var k=1;k<nrows;k++){
#             classstr = '.r'+k+'.c'+i;
#             tempcol[k-1] = rows[k].querySelectorAll(classstr)[0].querySelectorAll(".data_cell")[0].innerHTML;
#         }
#         data[i-1]=tempcol;
#     }
#     // Generate non-coder readable python code to put data into a DataFrame.
#     var pythoncode = "";
#     var dataframe_param = "{";
#     for (var i=0;i<(ncols-1);i++){
#         pythoncode += escnamestr[i]+"=["+data[i]+"]\n";
#         dataframe_param +="\""+colnames[i]+"\":"+escnamestr[i]+",\n";
#     }
#     dataframe_param +="}"
#     pythoncode += values[0]+ "= pd.DataFrame("+dataframe_param+")\n";
#     pythoncode += "print('DataFrame `"+values[0]+"`:')\n";
#     pythoncode += values[0];
#
#
#     // TODO: Insert a cell below the cell containing the table. Load with Python code that is non-coder readable.
#     // Run the cell to create the DataFrame.
#     //alert(pythoncode);
#     select_containing_cell(parentTable); //Make sure the cell containing the table is selected by Jupyter.
#     Jupyter.notebook.insert_cell_below();
#     Jupyter.notebook.select_next(true);
#     Jupyter.notebook.focus_cell();
#     var currentcell = Jupyter.notebook.get_selected_cell();
#     currentcell.set_text(pythoncode);
#     currentcell.execute();
#  }+')();';
#
# function data_table_to_Pandas(tableID){
#     // Use dialog to get user choice for name of the DataFrame. Assumes Pandas import as `pd`.
#     var instructions = "Provide a name for the Pandas DataFrame:";
#     var fields = ["Name"]
#     input_dialog("DFName_dia", table_data_to_named_DF, tableID, instructions,fields)
#
# }
#
# data_table_to_Pandas("it_1596221661269")

# %%
# If no data table appears in the output of this cell, run the cell to display the table.
try:
    from input_table import *
except (ImportError, FileNotFoundError) as e:
    from IPython.display import HTML
    print("Table editing will not work because `jupyter_datainputtable` module is not installed in python kernel")
display(HTML('<table class="input_table" id="it_1596744423578"><tbody> <tr class="input_table r0">  <td class="input_table r0 c0"><button class="edit_btn" onclick="edit_input_table(\'it_1596744423578\');">Edit Data</button></td><td class="input_table r0 c1"><span class="table_label">time(s)</span></td><td class="input_table r0 c2"><span class="table_label">temperature(C)</span></td> </tr> <tr class="input_table r1"><td class="input_table r1 c0"><span class="table_label">0</span></td>  <td class="input_table r1 c1"><span class="data_cell"></span></td>  <td class="input_table r1 c2"><span class="data_cell"></span></td> </tr> <tr class="input_table r2"><td class="input_table r2 c0"><span class="table_label">1</span></td>  <td class="input_table r2 c1"><span class="data_cell"></span></td>  <td class="input_table r2 c2"><span class="data_cell"></span></td> </tr> <tr class="input_table r3"><td class="input_table r3 c0"><span class="table_label">2</span></td>  <td class="input_table r3 c1"><span class="data_cell"></span></td>  <td class="input_table r3 c2"><span class="data_cell"></span></td> </tr> <tr class="input_table r4"><td class="input_table r4 c0"><span class="table_label">3</span></td>  <td class="input_table r4 c1"><span class="data_cell"></span></td>  <td class="input_table r4 c2"><span class="data_cell"></span></td> </tr></tbody></table>'))
# Out:
# <table class="input_table" id="it_1596744423578"><tbody> <tr class="input_table r0">  <td class="input_table r0 c0"><button class="lock_btn" onclick="lock_labels('it_1596744423578')">Lock Column and Row Labels</button></td><td class="input_table r0 c1"><input class="table_label" type="text" size="15" value="Col_0" style="font-weight:bold;" onblur="record_input(this)"></input></td><td class="input_table r0 c2"><input class="table_label" type="text" size="15" value="Col_1" style="font-weight:bold;" onblur="record_input(this)"></input></td> </tr> <tr class="input_table r1"><td class="input_table r1 c0"><input class="table_label" type="text" size="7" value="0" style="font-weight:bold;" onblur="record_input(this)"></input></td>  <td class="input_table r1 c1"><input class="data_cell" type="text" size="7" onblur="record_input(this)"></input></td>  <td class="input_table r1 c2"><input class="data_cell" type="text" size="7" onblur="record_input(this)"></input></td> </tr> <tr class="input_tabl
# ...

# %%
# If no data table appears in the output of this cell, run the cell to display the table.
try:
    from input_table import *
except (ImportError, FileNotFoundError) as e:
    from IPython.display import HTML
    print("Table editing will not work because `jupyter_datainputtable` module is not installed in python kernel")
display(HTML('<table class="input_table" id="it_1596221661269"><tbody> <tr class="input_table r0">  <td class="input_table r0 c0"><button class="edit_btn" onclick="edit_input_table(\'it_1596221661269\');">Edit Data</button></td><td class="input_table r0 c1"><span class="table_label">A</span></td><td class="input_table r0 c2"><span class="table_label">B(g)</span></td><td class="input_table r0 c3"><span class="table_label">C</span></td> </tr> <tr class="input_table r1"><td class="input_table r1 c0"><span class="table_label">0</span></td>  <td class="input_table r1 c1"><span class="data_cell">1.1</span></td>  <td class="input_table r1 c2"><span class="data_cell">2.1</span></td>  <td class="input_table r1 c3"><span class="data_cell">3.1</span></td> </tr> <tr class="input_table r2"><td class="input_table r2 c0"><span class="table_label">1</span></td>  <td class="input_table r2 c1"><span class="data_cell">1.2</span></td>  <td class="input_table r2 c2"><span class="data_cell">2.2</span></td>  <td class="input_table r2 c3"><span class="data_cell">3.2</span></td> </tr> <tr class="input_table r3"><td class="input_table r3 c0"><span class="table_label">2</span></td>  <td class="input_table r3 c1"><span class="data_cell">1.3</span></td>  <td class="input_table r3 c2"><span class="data_cell">2.3</span></td>  <td class="input_table r3 c3"><span class="data_cell">3.3</span></td> </tr></tbody></table>'))

# %%
A=[1.1,1.2,1.3]
B_g_=[2.1,2.2,2.3]
C=[3.1,3.2,3.3]
tst3= pd.DataFrame({"A":A,
"B(g)":B_g_,
"C":C,
})
print('DataFrame `tst3`:')
tst3

# %%
import pandas as pd

# %%
tst = pd.read_html('<table class="input_table" id="it_1596221661269"><tbody> <tr class="input_table r0">  <td class="input_table r0 c0"><button class="edit_btn" onclick="edit_input_table(\'it_1596221661269\');">Edit Data</button></td><td class="input_table r0 c1"><span class="table_label">A</span></td><td class="input_table r0 c2"><span class="table_label">B(g)</span></td><td class="input_table r0 c3"><span class="table_label">C</span></td> </tr> <tr class="input_table r1"><td class="input_table r1 c0"><span class="table_label">0</span></td>  <td class="input_table r1 c1"><span class="data_cell">1.1</span></td>  <td class="input_table r1 c2"><span class="data_cell">2.1</span></td>  <td class="input_table r1 c3"><span class="data_cell">3.1</span></td> </tr> <tr class="input_table r2"><td class="input_table r2 c0"><span class="table_label">1</span></td>  <td class="input_table r2 c1"><span class="data_cell">1.2</span></td>  <td class="input_table r2 c2"><span class="data_cell">2.2</span></td>  <td class="input_table r2 c3"><span class="data_cell">3.2</span></td> </tr> <tr class="input_table r3"><td class="input_table r3 c0"><span class="table_label">2</span></td>  <td class="input_table r3 c1"><span class="data_cell">1.3</span></td>  <td class="input_table r3 c2"><span class="data_cell">2.3</span></td>  <td class="input_table r3 c3"><span class="data_cell">3.3</span></td> </tr></tbody></table>')

# %%
from IPython.display import HTML
from IPython.display import Javascript as JS

jsstr="""
<script type="text/javascript">

function get_dialog_input(dialog_id){
    var dialog = document.getElementById(dialog_id)
    var inputs = dialog.querySelectorAll('input');
    input_values = [];
    for (var i=0;i<inputs.length;i++){
        input_values[i]=inputs[i].value;
    }
    dialog.remove();
    document.getElementById("back_dialog").remove();
    alert(input_values);
}

function pyth_ass(){
    //var values = ipd.get_dialog_input()
    //var pythstr = 'fn = '+values[0]+'\\n';
    //pythstr += 'age ='+values[2]+'\\n';
    //alert(pythstr);
    var dialog = document.getElementById("name_age_diag")
    dialog.remove();
}
</script>
"""

display(HTML(jsstr))

# %%
# %%javascript
#
# 8
# var pyth_ass = '('+function (){
#     var dialog = document.getElementById("df_name_dialog")
#     var inputs = dialog.querySelectorAll('input');
#     var values = [];
#     for (var i=0;i<inputs.length;i++){
#         values[i]=inputs[i].value;
#     }
#     dialog.remove();
#     pythstr = 'dfname= "'+values[0]+'"\n';
#     alert(pythstr);
# }+')();';
#
# input_dialog("df_name_dialog",pyth_ass,"Please provide a one word name for the DataFrame.",["DataFrame Name"]);

# %%
type(pd)

# %%
type(pd.DataFrame())

# %%
isinstance(pd.DataFrame(), pd.core.frame.DataFrame)

# %%
try:
    print(isinstance(pandas.DataFrame(), pandas.core.frame.DataFrame))
except NameError as e:
    print(e)
