# %%
from input_table import *
import pandas as pd
# Out:
# <script type="text/javascript">//Javascript for input_table to use in Jupyter notebook
# //Jonathan Gutow <gutow@uwosh.edu> March 24, 2019
# //license GPL V3 or greater.
#
# //Get input table dimensions and build
# function get_table_dim(){
#     Jupyter.notebook.insert_cell_below();
#     Jupyter.notebook.select_next(true);
#     Jupyter.notebook.focus_cell();
#     var currentcell = Jupyter.notebook.get_selected_cell();
# //    var htmlstr =`
# //    <div id="input_table_dim_dlg" style="border:thick;border-color:red;border-style:solid;">
# //      <div>Set table size remembering to include enough rows and columns for labels.</div>
# //      <table id="init_input_table_dim"><tr>
# //        <td> Rows:</td><td><input id="init_row_dim" type="text" size="7" value="2"
# //          onblur="record_input(this)"></input></td>
# //        <td>Columns:</td><td><input id="init_col_dim" type="text" size="7" value="2"
# //          onblur="record_input(this)"></input></td>
# ...

# %%
# If no data table appears in the output of this cell, run the cell to display the table.
try:
    from input_table import *
except (ImportError, FileNotFoundError) as e:
    from IPython.display import HTML
    print("Table editing will not work because `jupyter_datainputtable` module is not installed in python kernel")
display(HTML('<table class="input_table" id="it_1596764935828"><tbody> <tr class="input_table r0">  <th class="input_table r0 c0"><select class="form-control table-actions" onchange="var lastvalue = this.value;this.value = &quot;Table Actions&quot;;if(lastvalue==&quot;Edit Data&quot;){edit_input_table(&quot;it_1596764935828&quot;);}if(lastvalue==&quot;Data to Pandas...&quot;){data_table_to_Pandas(&quot;it_1596764935828&quot;);}"><option title="Things you can do to this table.">Table Actions</option><option title="Start editing the data.">Edit Data</option><option title="Create a Panda DataFrame from table.">Data to Pandas...</option></select></th><th class="input_table r0 c1"><span class="table_label">Time(s)</span></th><th class="input_table r0 c2"><span class="table_label">Temperature(C)</span></th> </tr> <tr class="input_table r1"><th class="input_table r1 c0"><span class="table_label">0</span></th>  <td class="input_table r1 c1"><span class="data_cell">1</span></td>  <td class="input_table r1 c2"><span class="data_cell">0</span></td> </tr> <tr class="input_table r2"><th class="input_table r2 c0"><span class="table_label">1</span></th>  <td class="input_table r2 c1"><span class="data_cell">2</span></td>  <td class="input_table r2 c2"><span class="data_cell">1</span></td> </tr> <tr class="input_table r3"><th class="input_table r3 c0"><span class="table_label">2</span></th>  <td class="input_table r3 c1"><span class="data_cell">3</span></td>  <td class="input_table r3 c2"><span class="data_cell">1.6</span></td> </tr> <tr class="input_table r4"><th class="input_table r4 c0"><span class="table_label">3</span></th>  <td class="input_table r4 c1"><span class="data_cell">4</span></td>  <td class="input_table r4 c2"><span class="data_cell">2.1</span></td> </tr></tbody></table>'))
# Out:
# <table class="input_table" id="it_1596764935828"><tbody> <tr class="input_table r0">  <th class="input_table r0 c0"><select class="form-control table-actions" onchange="var lastvalue = this.value;this.value = &quot;Table Actions&quot;;if(lastvalue==&quot;Edit Data&quot;){edit_input_table(&quot;it_1596764935828&quot;);}if(lastvalue==&quot;Data to Pandas...&quot;){data_table_to_Pandas(&quot;it_1596764935828&quot;);}"><option title="Things you can do to this table.">Table Actions</option><option title="Start editing the data.">Edit Data</option><option title="Create a Panda DataFrame from table.">Data to Pandas...</option></select></th><th class="input_table r0 c1"><span class="table_label">Time(s)</span></th><th class="input_table r0 c2"><span class="table_label">Temperature(C)</span></th> </tr> <tr class="input_table r1"><th class="input_table r1 c0"><span class="table_label">0</span></th>  <td class="input_table r1 c1"><span class="data_cell">1</span></td>  <td class="input_table r1 
# ...

# %%
Time_s_=[1,2,3,4]
Temperature_C_=[0,1,1.6,2.1]
try: # Wrapping assigment in `try:...except:` allows us to check if Pandas is available.
    tst1= pd.DataFrame({"Time(s)":Time_s_,
    "Temperature(C)":Temperature_C_,
    })
except NameError as e:
    print("Sorry, Pandas needs to be imported using the statement `import pandas as pd` first.")
    tst1 = "undefined"
print('DataFrame `tst1`:')
tst1
# Out:
# DataFrame `tst1`:
#    Time(s)  Temperature(C)
# 0        1             0.0
# 1        2             1.0
# 2        3             1.6
# 3        4             2.1

# %%
# If no data table appears in the output of this cell, run the cell to display the table.
try:
    from input_table import *
except (ImportError, FileNotFoundError) as e:
    from IPython.display import HTML
    print("Table editing will not work because `jupyter_datainputtable` module is not installed in python kernel")
display(HTML('<table class="input_table" id="it_1596912727993"><tbody> <tr class="input_table r0">  <th class="input_table r0 c0"><select class="form-control table-actions" onchange="var lastvalue = this.value;this.value = &quot;Table Actions&quot;;if(lastvalue==&quot;Edit Data&quot;){edit_input_table(&quot;it_1596912727993&quot;);}if(lastvalue==&quot;Data to Pandas...&quot;){data_table_to_Pandas(&quot;it_1596912727993&quot;);}"><option title="Things you can do to this table.">Table Actions</option><option title="Start editing the data.">Edit Data</option><option title="Create a Panda DataFrame from table.">Data to Pandas...</option></select></th><th class="input_table r0 c1"><span class="table_label">P(Torr)</span></th><th class="input_table r0 c2"><span class="table_label">err_P(Torr)</span></th><th class="input_table r0 c3"><span class="table_label">Bulb Mass(g)</span></th><th class="input_table r0 c4"><span class="table_label">err_Bulb Mass(g)</span></th> </tr> <tr class="input_table r1"><th class="input_table r1 c0"><span class="table_label">0</span></th>  <td class="input_table r1 c1"><span class="data_cell">0</span></td>  <td class="input_table r1 c2"><span class="data_cell">0.05</span></td>  <td class="input_table r1 c3"><span class="data_cell">50.1234</span></td>  <td class="input_table r1 c4"><span class="data_cell">0.0001</span></td> </tr> <tr class="input_table r2"><th class="input_table r2 c0"><span class="table_label">1</span></th>  <td class="input_table r2 c1"><span class="data_cell">20.0</span></td>  <td class="input_table r2 c2"><span class="data_cell">0.05</span></td>  <td class="input_table r2 c3"><span class="data_cell">50.1244</span></td>  <td class="input_table r2 c4"><span class="data_cell">0.0001</span></td> </tr> <tr class="input_table r3"><th class="input_table r3 c0"><span class="table_label">2</span></th>  <td class="input_table r3 c1"><span class="data_cell">40</span></td>  <td class="input_table r3 c2"><span class="data_cell">0.05</span></td>  <td class="input_table r3 c3"><span class="data_cell">50.1255</span></td>  <td class="input_table r3 c4"><span class="data_cell">0.0001</span></td> </tr> <tr class="input_table r4"><th class="input_table r4 c0"><span class="table_label">3</span></th>  <td class="input_table r4 c1"><span class="data_cell">80.0</span></td>  <td class="input_table r4 c2"><span class="data_cell">0.05</span></td>  <td class="input_table r4 c3"><span class="data_cell">50.1275</span></td>  <td class="input_table r4 c4"><span class="data_cell">0.0001</span></td> </tr> <tr class="input_table r5"><th class="input_table r5 c0"><span class="table_label">4</span></th>  <td class="input_table r5 c1"><span class="data_cell">160.0</span></td>  <td class="input_table r5 c2"><span class="data_cell">0.05</span></td>  <td class="input_table r5 c3"><span class="data_cell">50.1315</span></td>  <td class="input_table r5 c4"><span class="data_cell">0.0001</span></td> </tr></tbody></table>'))
# Out:
# <table class="input_table" id="it_1596912727993"><tbody> <tr class="input_table r0">  <th class="input_table r0 c0"><select class="form-control table-actions" onchange="var lastvalue = this.value;this.value = &quot;Table Actions&quot;;if(lastvalue==&quot;Edit Data&quot;){edit_input_table(&quot;it_1596912727993&quot;);}if(lastvalue==&quot;Data to Pandas...&quot;){data_table_to_Pandas(&quot;it_1596912727993&quot;);}"><option title="Things you can do to this table.">Table Actions</option><option title="Start editing the data.">Edit Data</option><option title="Create a Panda DataFrame from table.">Data to Pandas...</option></select></th><th class="input_table r0 c1"><span class="table_label">P(Torr)</span></th><th class="input_table r0 c2"><span class="table_label">err_P(Torr)</span></th><th class="input_table r0 c3"><span class="table_label">Bulb Mass(g)</span></th><th class="input_table r0 c4"><span class="table_label">err_Bulb Mass(g)</span></th> </tr> <tr class="input_table r1"><th c
# ...

# %%
P_Torr_=[0,20.0,40,80.0,160.0]
err_P_Torr_=[0.05,0.05,0.05,0.05,0.05]
Bulb_Mass_g_=[50.1234,50.1244,50.1255,50.1275,50.1315]
err_Bulb_Mass_g_=[0.0001,0.0001,0.0001,0.0001,0.0001]
try: # Wrapping assigment in `try:...except:` allows us to check if Pandas is available.
    tst2= pd.DataFrame({"P(Torr)":P_Torr_,
    "err_P(Torr)":err_P_Torr_,
    "Bulb Mass(g)":Bulb_Mass_g_,
    "err_Bulb Mass(g)":err_Bulb_Mass_g_,
    }, index = ["0", "1", "P 2", "3", "4", ])
except NameError as e:
    print("Sorry, Pandas needs to be imported using the statement `import pandas as pd` first.")
    tst2 = "undefined"
print('DataFrame `tst2`:')
tst2
# Out:
# DataFrame `tst2`:
#      P(Torr)  err_P(Torr)  Bulb Mass(g)  err_Bulb Mass(g)
# 0        0.0         0.05       50.1234            0.0001
# 1       20.0         0.05       50.1244            0.0001
# P 2     40.0         0.05       50.1255            0.0001
# 3       80.0         0.05       50.1275            0.0001
# 4      160.0         0.05       50.1315            0.0001

# %%
import matplotlib as plt
gastst.plot(x="P(Torr)",y="Bulb Mass(g)")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-0ee9383a82bd> in <module>
# ----> 1 import matplotlib as plt
#       2 gastst.plot(x="P(Torr)",y="Bulb Mass(g)")
#
# ModuleNotFoundError: No module named 'matplotlib'
