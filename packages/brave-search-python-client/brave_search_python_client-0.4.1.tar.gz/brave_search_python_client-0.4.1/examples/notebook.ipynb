# %%
from brave_search_python_client import BraveSearch, WebSearchRequest
# Out:
# Brave Search Python Client loaded in v0.0.7

# %%
import os

from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("BRAVE_SEARCH_API_KEY")
if not api_key:
    msg = "BRAVE_SEARCH_API_KEY is not set in .env file"
    raise ValueError(msg)
# Out:
# BRAVE_SEARCH_API_KEY found

# %%
bs = BraveSearch()
response = await bs.web(WebSearchRequest(q="jupyter"))
# Out:
# {
#   "type": "search",
#   "discussions": null,
#   "faq": null,
#   "infobox": null,
#   "locations": null,
#   "mixed": {
#     "type": "mixed",
#     "main": [
#       {
#         "type": "web",
#         "index": 0,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 1,
#         "all": false
#       },
#       {
#         "type": "videos",
#         "index": null,
#         "all": true
#       },
#       {
#         "type": "web",
#         "index": 2,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 3,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 4,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 5,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 6,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 7,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 8,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 9,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 10,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 11,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 12,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 13,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 14,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 15,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 16,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 17,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 18,
#         "all": false
#       },
#       {
#         "type": "web",
#         "index": 19,
#         "all": false
#       }
#     ],
#     "top": [],
#     "side": []
#   },
#   "news": null,
#   "query": {
#     "original": "jupyter",
#     "show_strict_warning": false,
#     "altered": null,
#     "safesearch": null,
#     "is_navigational": true,
#     "is_geolocal": null,
#     "local_decision": null,
#     "local_locations_idx": null,
#     "is_trending": null,
#     "is_news_breaking": false,
#     "ask_for_location": null,
#     "language": null,
#     "spellcheck_off": true,
#     "country": "all",
#     "bad_results": false,
#     "should_fallback": false,
#     "lat": null,
#     "long": null,
#     "postal_code": "",
#     "city": "",
#     "state": "",
#     "header_country": "",
#     "more_results_available": true,
#     "custom_location_label": null,
#     "reddit_cluster": null
#   },
#   "videos": {
#     "type": "videos",
#     "results": [
#       {
#         "title": "Jupyter Notebook Tutorial: Introduction, Setup, and Walkthrough ...",
#         "url": "https://www.youtube.com/watch?v=HW29067qVWk",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "In this Python Tutorial, we will be learning how to install, setup, and use Jupyter Notebooks. Jupyter Notebooks have become very popular in the last few yea...",
#         "page_age": "2016-09-22T13:35:52",
#         "page_fetched": null,
#         "profile": null,
#         "language": null,
#         "family_friendly": false,
#         "type": "video_result",
#         "video": {
#           "duration": null,
#           "views": null,
#           "creator": null,
#           "publisher": null,
#           "thumbnail": null,
#           "tags": null,
#           "author": null,
#           "requires_subscription": null
#         },
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "youtube.com",
#           "hostname": "www.youtube.com",
#           "favicon": "https://imgs.search.brave.com/Wg4wjE5SHAargkzePU3eSLmWgVz84BEZk1SjSglJK_U/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvOTkyZTZiMWU3/YzU3Nzc5YjExYzUy/N2VhZTIxOWNlYjM5/ZGVjN2MyZDY4Nzdh/ZDYzMTYxNmI5N2Rk/Y2Q3N2FkNy93d3cu/eW91dHViZS5jb20v",
#           "path": "\u203a watch"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/KVr6ucOP1Q4yYjptPXL-XHyVn63v7LT1AjQCu8oBOLA/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9pLnl0/aW1nLmNvbS92aS9I/VzI5MDY3cVZXay9t/YXhyZXNkZWZhdWx0/LmpwZw",
#           "original": "https://i.ytimg.com/vi/HW29067qVWk/maxresdefault.jpg"
#         },
#         "age": "September 22, 2016"
#       },
#       {
#         "title": "How to use Jupyter notebooks for data analysis (2024 tutorial) ...",
#         "url": "https://www.youtube.com/watch?v=bqw5-8f-cEI",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Ever wanted to take up data science or data analysis? Jupyter notebooks are one of the essential tools you'll need to get started. This tutorial will take yo...",
#         "page_age": "2024-02-26T12:00:27",
#         "page_fetched": null,
#         "profile": null,
#         "language": null,
#         "family_friendly": false,
#         "type": "video_result",
#         "video": {
#           "duration": null,
#           "views": null,
#           "creator": null,
#           "publisher": null,
#           "thumbnail": null,
#           "tags": null,
#           "author": null,
#           "requires_subscription": null
#         },
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "youtube.com",
#           "hostname": "www.youtube.com",
#           "favicon": "https://imgs.search.brave.com/Wg4wjE5SHAargkzePU3eSLmWgVz84BEZk1SjSglJK_U/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvOTkyZTZiMWU3/YzU3Nzc5YjExYzUy/N2VhZTIxOWNlYjM5/ZGVjN2MyZDY4Nzdh/ZDYzMTYxNmI5N2Rk/Y2Q3N2FkNy93d3cu/eW91dHViZS5jb20v",
#           "path": "\u203a watch"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/zpa-1RuRNWeGVcNRr5p7i15xJGExxOgZ9_Z1pU7X7jY/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9pLnl0/aW1nLmNvbS92aS9i/cXc1LThmLWNFSS9t/YXhyZXNkZWZhdWx0/LmpwZw",
#           "original": "https://i.ytimg.com/vi/bqw5-8f-cEI/maxresdefault.jpg"
#         },
#         "age": "February 26, 2024"
#       },
#       {
#         "title": "Jupyter Notebooks vs Python Scripts | When to Use Which? - YouTube",
#         "url": "https://www.youtube.com/watch?v=0Jw8seqai18",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "\ud83d\udca1 Learn how to design great software in 7 steps: https://arjan.codes/designguide.Jupiter Notebooks vs. Python Scripts? Yes, you read that right! For the fir...",
#         "page_age": "2023-08-18T15:00:01",
#         "page_fetched": null,
#         "profile": null,
#         "language": null,
#         "family_friendly": false,
#         "type": "video_result",
#         "video": {
#           "duration": null,
#           "views": null,
#           "creator": null,
#           "publisher": null,
#           "thumbnail": null,
#           "tags": null,
#           "author": null,
#           "requires_subscription": null
#         },
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "youtube.com",
#           "hostname": "www.youtube.com",
#           "favicon": "https://imgs.search.brave.com/Wg4wjE5SHAargkzePU3eSLmWgVz84BEZk1SjSglJK_U/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvOTkyZTZiMWU3/YzU3Nzc5YjExYzUy/N2VhZTIxOWNlYjM5/ZGVjN2MyZDY4Nzdh/ZDYzMTYxNmI5N2Rk/Y2Q3N2FkNy93d3cu/eW91dHViZS5jb20v",
#           "path": "\u203a watch"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/o3GsGMqGIFgqL6GZZGBhsC4YYhBELbqXEcGRcfIaeWw/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9pLnl0/aW1nLmNvbS92aS8w/Snc4c2VxYWkxOC9t/YXhyZXNkZWZhdWx0/LmpwZw",
#           "original": "https://i.ytimg.com/vi/0Jw8seqai18/maxresdefault.jpg"
#         },
#         "age": "August 18, 2023"
#       },
#       {
#         "title": "Why I stopped using Jupyter Notebooks",
#         "url": "https://www.youtube.com/watch?v=qFvInA7DKuE",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world on YouTube.",
#         "page_age": null,
#         "page_fetched": null,
#         "profile": null,
#         "language": null,
#         "family_friendly": false,
#         "type": "video_result",
#         "video": {
#           "duration": null,
#           "views": null,
#           "creator": null,
#           "publisher": null,
#           "thumbnail": null,
#           "tags": null,
#           "author": null,
#           "requires_subscription": null
#         },
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "youtube.com",
#           "hostname": "www.youtube.com",
#           "favicon": "https://imgs.search.brave.com/Wg4wjE5SHAargkzePU3eSLmWgVz84BEZk1SjSglJK_U/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvOTkyZTZiMWU3/YzU3Nzc5YjExYzUy/N2VhZTIxOWNlYjM5/ZGVjN2MyZDY4Nzdh/ZDYzMTYxNmI5N2Rk/Y2Q3N2FkNy93d3cu/eW91dHViZS5jb20v",
#           "path": "\u203a watch"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/RvPyYjk0qiDIfZduvBBJKX-SfNZICG7Y-saqFxI_b34/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9pLnl0/aW1nLmNvbS92aS9x/RnZJbkE3REt1RS9o/cWRlZmF1bHQuanBn",
#           "original": "https://i.ytimg.com/vi/qFvInA7DKuE/hqdefault.jpg"
#         },
#         "age": null
#       },
#       {
#         "title": "Introduction to Jupyter Notebooks: explore the main functionalities ...",
#         "url": "https://www.youtube.com/watch?v=QdE9XvACugg",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Hello friends,This is my course Hands-on Data Science which was released back in 2020 to help aspiring data scientists learn how the end-to-end process of a ...",
#         "page_age": "2024-04-08T20:36:53",
#         "page_fetched": null,
#         "profile": null,
#         "language": null,
#         "family_friendly": false,
#         "type": "video_result",
#         "video": {
#           "duration": null,
#           "views": null,
#           "creator": null,
#           "publisher": null,
#           "thumbnail": null,
#           "tags": null,
#           "author": null,
#           "requires_subscription": null
#         },
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "youtube.com",
#           "hostname": "www.youtube.com",
#           "favicon": "https://imgs.search.brave.com/Wg4wjE5SHAargkzePU3eSLmWgVz84BEZk1SjSglJK_U/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvOTkyZTZiMWU3/YzU3Nzc5YjExYzUy/N2VhZTIxOWNlYjM5/ZGVjN2MyZDY4Nzdh/ZDYzMTYxNmI5N2Rk/Y2Q3N2FkNy93d3cu/eW91dHViZS5jb20v",
#           "path": "\u203a watch"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/f4UYo8wfrafHBlpNeq_RLpTiA0ceQuma7wT3zgGb9Do/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9pLnl0/aW1nLmNvbS92aS9R/ZEU5WHZBQ3VnZy9t/YXhyZXNkZWZhdWx0/LmpwZw",
#           "original": "https://i.ytimg.com/vi/QdE9XvACugg/maxresdefault.jpg"
#         },
#         "age": "April 8, 2024"
#       },
#       {
#         "title": "Python Crash Course: Part 3 - Using Jupyter Notebooks - YouTube",
#         "url": "https://www.youtube.com/watch?v=5wibG8wOXB8",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Are you ready to have more impact at work with analytics and data science powered by Python? This crash course is designed for ANY professional to learn the ...",
#         "page_age": "2024-01-16T14:00:05",
#         "page_fetched": null,
#         "profile": null,
#         "language": null,
#         "family_friendly": false,
#         "type": "video_result",
#         "video": {
#           "duration": null,
#           "views": null,
#           "creator": null,
#           "publisher": null,
#           "thumbnail": null,
#           "tags": null,
#           "author": null,
#           "requires_subscription": null
#         },
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "youtube.com",
#           "hostname": "www.youtube.com",
#           "favicon": "https://imgs.search.brave.com/Wg4wjE5SHAargkzePU3eSLmWgVz84BEZk1SjSglJK_U/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvOTkyZTZiMWU3/YzU3Nzc5YjExYzUy/N2VhZTIxOWNlYjM5/ZGVjN2MyZDY4Nzdh/ZDYzMTYxNmI5N2Rk/Y2Q3N2FkNy93d3cu/eW91dHViZS5jb20v",
#           "path": "\u203a watch"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/R4UUSbIRlALCJkjoneCgN5IZ3kcd3v_8IvbJMIzC5IA/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9pLnl0/aW1nLmNvbS92aS81/d2liRzh3T1hCOC9t/YXhyZXNkZWZhdWx0/LmpwZw",
#           "original": "https://i.ytimg.com/vi/5wibG8wOXB8/maxresdefault.jpg"
#         },
#         "age": "January 16, 2024"
#       }
#     ],
#     "mutated_by_goggles": false
#   },
#   "web": {
#     "type": "search",
#     "results": [
#       {
#         "title": "Project Jupyter | Home",
#         "url": "https://jupyter.org/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "The <strong>Jupyter</strong> Notebook is a web-based interactive computing platform. The notebook combines live code, equations, narrative text, visualizations, interactive dashboards and other media.",
#         "page_age": "2023-08-02T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "Jupyter",
#           "long_name": "jupyter.org",
#           "url": "https://jupyter.org/",
#           "img": "https://imgs.search.brave.com/1pbUuNwZEI2a0_ftpb2kspoKPE1hSYrFvtXpYLVM0Ms/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYmJlMWM3ZWNk/NTA5ODI2NTE1Njc5/Y2NmNWEzOWMxMzll/ZjI0YjcwOWM2MDA2/OWQ3NWNjZDdlOGVm/ZmQ1M2Q2ZS9qdXB5/dGVyLm9yZy8"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "jupyter.org",
#           "hostname": "jupyter.org",
#           "favicon": "https://imgs.search.brave.com/1pbUuNwZEI2a0_ftpb2kspoKPE1hSYrFvtXpYLVM0Ms/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYmJlMWM3ZWNk/NTA5ODI2NTE1Njc5/Y2NmNWEzOWMxMzll/ZjI0YjcwOWM2MDA2/OWQ3NWNjZDdlOGVm/ZmQ1M2Q2ZS9qdXB5/dGVyLm9yZy8",
#           "path": ""
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/1J0y6HKjfGhtfsagfDG3vDp-7fRbS0Glj9NpI0F_7B0/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9qdXB5/dGVyLm9yZy9hc3Nl/dHMvc2hhcmUucG5n",
#           "original": "https://jupyter.org/assets/share.png"
#         },
#         "age": "August 2, 2023",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": "generic",
#         "cluster": [
#           {
#             "title": "Try",
#             "url": "https://jupyter.org/try",
#             "is_source_local": false,
#             "is_source_both": false,
#             "description": "The <strong>Jupyter</strong> Notebook is a web-based interactive computing platform. The notebook combines live code, equations, narrative text, visualizations, interactive dashboards and other media.",
#             "page_age": null,
#             "page_fetched": null,
#             "profile": null,
#             "language": null,
#             "family_friendly": true
#           },
#           {
#             "title": "About",
#             "url": "https://jupyter.org/about",
#             "is_source_local": false,
#             "is_source_both": false,
#             "description": "The <strong>Jupyter</strong> Notebook is a web-based interactive computing platform. The notebook combines live code, equations, narrative text, visualizations, interactive dashboards and other media.",
#             "page_age": null,
#             "page_fetched": null,
#             "profile": null,
#             "language": null,
#             "family_friendly": true
#           },
#           {
#             "title": "Install",
#             "url": "https://jupyter.org/install",
#             "is_source_local": false,
#             "is_source_both": false,
#             "description": "The <strong>Jupyter</strong> Notebook is a web-based interactive computing platform. The notebook combines live code, equations, narrative text, visualizations, interactive dashboards and other media.",
#             "page_age": null,
#             "page_fetched": null,
#             "profile": null,
#             "language": null,
#             "family_friendly": true
#           },
#           {
#             "title": "Get Involved",
#             "url": "https://jupyter.org/community",
#             "is_source_local": false,
#             "is_source_both": false,
#             "description": "The <strong>Jupyter</strong> Notebook is a web-based interactive computing platform. The notebook combines live code, equations, narrative text, visualizations, interactive dashboards and other media.",
#             "page_age": null,
#             "page_fetched": null,
#             "profile": null,
#             "language": null,
#             "family_friendly": true
#           }
#         ],
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "Project Jupyter - Wikipedia",
#         "url": "https://en.wikipedia.org/wiki/Project_Jupyter",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Project <strong>Jupyter</strong> (/\u02c8d\u0292u\u02d0p\u026at\u0259r/ ) is a project to develop open-source software, open standards, and services for interactive computing across multiple programming languages. It was spun off from IPython in 2014 by Fernando P\u00e9rez and Brian Granger. Project <strong>Jupyter</strong>&#x27;s name is a reference to ...",
#         "page_age": "2024-12-21T23:40:14",
#         "page_fetched": null,
#         "profile": {
#           "name": "Wikipedia",
#           "long_name": "en.wikipedia.org",
#           "url": "https://en.wikipedia.org/wiki/Project_Jupyter",
#           "img": "https://imgs.search.brave.com/m6XxME4ek8DGIUcEPCqjRoDjf2e54EwL9pQzyzogLYk/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": {
#           "news": null,
#           "buttons": [
#             {
#               "type": "button_result",
#               "title": "History",
#               "url": "https://en.wikipedia.org/wiki/Project_Jupyter#History"
#             },
#             {
#               "type": "button_result",
#               "title": "Jupyter Notebook",
#               "url": "https://en.wikipedia.org/wiki/Project_Jupyter#Jupyter_Notebook"
#             }
#           ],
#           "videos": null,
#           "images": null
#         },
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "en.wikipedia.org",
#           "hostname": "en.wikipedia.org",
#           "favicon": "https://imgs.search.brave.com/m6XxME4ek8DGIUcEPCqjRoDjf2e54EwL9pQzyzogLYk/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw",
#           "path": "\u203a wiki  \u203a Project_Jupyter"
#         },
#         "thumbnail": null,
#         "age": "2 weeks ago",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "Jupyter Notebook Documentation \u2014 Jupyter Notebook 7.3.2 ...",
#         "url": "https://jupyter-notebook.readthedocs.io/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "<strong>Jupyter</strong> Notebook is a simplified notebook authoring application, and is a part of Project <strong>Jupyter</strong>, a large umbrella project centered around the goal of providing tools (and standards) for interactive computing with computational notebooks.",
#         "page_age": "2023-05-17T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "Readthedocs",
#           "long_name": "jupyter-notebook.readthedocs.io",
#           "url": "https://jupyter-notebook.readthedocs.io/",
#           "img": "https://imgs.search.brave.com/u7JXOaPTss7lTIDXUR-yjYf2WgvKgNd-FWzADfb47fs/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMzhmMzA4Y2Jk/N2Y3OTkwYzEwM2Ri/YzhhMjM3NTQ1Zjcz/NTczZTM4ZjNjOTJi/MGQ3MDZkYzNjYjRk/Zjg1NTk2Ny9qdXB5/dGVyLW5vdGVib29r/LnJlYWR0aGVkb2Nz/LmlvLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "jupyter-notebook.readthedocs.io",
#           "hostname": "jupyter-notebook.readthedocs.io",
#           "favicon": "https://imgs.search.brave.com/u7JXOaPTss7lTIDXUR-yjYf2WgvKgNd-FWzADfb47fs/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMzhmMzA4Y2Jk/N2Y3OTkwYzEwM2Ri/YzhhMjM3NTQ1Zjcz/NTczZTM4ZjNjOTJi/MGQ3MDZkYzNjYjRk/Zjg1NTk2Ny9qdXB5/dGVyLW5vdGVib29r/LnJlYWR0aGVkb2Nz/LmlvLw",
#           "path": ""
#         },
#         "thumbnail": null,
#         "age": "May 17, 2023",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "Project Jupyter \u00b7 GitHub",
#         "url": "https://github.com/jupyter",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Interactive Computing. Project <strong>Jupyter</strong> has 132 repositories available. Follow their code on GitHub.",
#         "page_age": "2023-05-30T08:50:05",
#         "page_fetched": null,
#         "profile": {
#           "name": "GitHub",
#           "long_name": "github.com",
#           "url": "https://github.com/jupyter",
#           "img": "https://imgs.search.brave.com/xxsA4YxzaR0cl-DBsH9-lpv2gsif3KMYgM87p26bs_o/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWQyNWM1NjA5/ZjZmZjNlYzI2MDNk/N2VkNmJhYjE2MzZl/MDY5ZTMxMDUzZmY1/NmU3NWIzNWVmMjk0/NTBjMjJjZi9naXRo/dWIuY29tLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "github.com",
#           "hostname": "github.com",
#           "favicon": "https://imgs.search.brave.com/xxsA4YxzaR0cl-DBsH9-lpv2gsif3KMYgM87p26bs_o/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWQyNWM1NjA5/ZjZmZjNlYzI2MDNk/N2VkNmJhYjE2MzZl/MDY5ZTMxMDUzZmY1/NmU3NWIzNWVmMjk0/NTBjMjJjZi9naXRo/dWIuY29tLw",
#           "path": "\u203a jupyter"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/VIMpuelY7tkaJsUFXmdqZA_THSwOMJ8k6SIBbQE8_-g/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9hdmF0/YXJzLmdpdGh1YnVz/ZXJjb250ZW50LmNv/bS91LzczODg5OTY_/cz0yMDAmYW1wO3Y9/NA",
#           "original": "https://avatars.githubusercontent.com/u/7388996?s=200&amp;v=4"
#         },
#         "age": "May 30, 2023",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "Built with Jupyter Book",
#         "url": "https://jupyterbook.org/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "We cannot provide a description for this page right now",
#         "page_age": "2021-03-02T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "Jupyterbook",
#           "long_name": "jupyterbook.org",
#           "url": "https://jupyterbook.org/",
#           "img": "https://imgs.search.brave.com/-PaH8gzRB5YjIlUV0QnfaThzFQOewysn32uFUSF649g/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMWNhOTU2ODVk/NDRkZGRmMGNjYjU5/YmU2YWVjMWZjZGUz/MDAxMTljMWY3MWZi/NDJiZjY4MjEzZmVm/MmQ5MGZjYi9qdXB5/dGVyYm9vay5vcmcv"
#         },
#         "language": "unk",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "jupyterbook.org",
#           "hostname": "jupyterbook.org",
#           "favicon": "https://imgs.search.brave.com/-PaH8gzRB5YjIlUV0QnfaThzFQOewysn32uFUSF649g/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMWNhOTU2ODVk/NDRkZGRmMGNjYjU5/YmU2YWVjMWZjZGUz/MDAxMTljMWY3MWZi/NDJiZjY4MjEzZmVm/MmQ5MGZjYi9qdXB5/dGVyYm9vay5vcmcv",
#           "path": ""
#         },
#         "thumbnail": null,
#         "age": "March 2, 2021",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "jupyter's Profile",
#         "url": "https://hub.docker.com/u/jupyter",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Welcome to the world&#x27;s largest container registry built for developers and open source contributors to find, use, and share their container images. Build, push and pull.",
#         "page_age": "2019-10-31T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "Docker",
#           "long_name": "hub.docker.com",
#           "url": "https://hub.docker.com/u/jupyter",
#           "img": "https://imgs.search.brave.com/S7njLdIrCeKw_shq07pmSSNoUDWH94kApohtGW-sT6E/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZDEyZWVlNDgz/ODk0YzAzODFjOTA0/Mjc0YjdmNGQzZTJk/Nzg0MjY0Njc5YzE1/NjI4ODdmNjU2MWEy/NzYzMTkxOS9odWIu/ZG9ja2VyLmNvbS8"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "hub.docker.com",
#           "hostname": "hub.docker.com",
#           "favicon": "https://imgs.search.brave.com/S7njLdIrCeKw_shq07pmSSNoUDWH94kApohtGW-sT6E/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZDEyZWVlNDgz/ODk0YzAzODFjOTA0/Mjc0YjdmNGQzZTJk/Nzg0MjY0Njc5YzE1/NjI4ODdmNjU2MWEy/NzYzMTkxOS9odWIu/ZG9ja2VyLmNvbS8",
#           "path": "\u203a u  \u203a jupyter"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/oy4944bwqnJmAacJGF0TSvbI4dpi_VnOZG0kqxNMm3A/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9kMzZq/Y2tzZGUxd3h6cS5j/bG91ZGZyb250Lm5l/dC9odWItdWkvQzA4/MFJKVzEucG5n",
#           "original": "https://d36jcksde1wxzq.cloudfront.net/hub-ui/C080RJW1.png"
#         },
#         "age": "October 31, 2019",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "GitHub - jupyter/notebook: Jupyter Interactive Notebook",
#         "url": "https://github.com/jupyter/notebook",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "<strong>Jupyter</strong> Interactive Notebook. Contribute to <strong>jupyter</strong>/notebook development by creating an account on GitHub.",
#         "page_age": "2021-05-03T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "GitHub",
#           "long_name": "github.com",
#           "url": "https://github.com/jupyter/notebook",
#           "img": "https://imgs.search.brave.com/xxsA4YxzaR0cl-DBsH9-lpv2gsif3KMYgM87p26bs_o/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWQyNWM1NjA5/ZjZmZjNlYzI2MDNk/N2VkNmJhYjE2MzZl/MDY5ZTMxMDUzZmY1/NmU3NWIzNWVmMjk0/NTBjMjJjZi9naXRo/dWIuY29tLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "software",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "github.com",
#           "hostname": "github.com",
#           "favicon": "https://imgs.search.brave.com/xxsA4YxzaR0cl-DBsH9-lpv2gsif3KMYgM87p26bs_o/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWQyNWM1NjA5/ZjZmZjNlYzI2MDNk/N2VkNmJhYjE2MzZl/MDY5ZTMxMDUzZmY1/NmU3NWIzNWVmMjk0/NTBjMjJjZi9naXRo/dWIuY29tLw",
#           "path": "\u203a jupyter  \u203a notebook"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/bfXWbZsgpllYMWJgmNA05bL03q7Aa06Af1UTynGTDYM/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9vcGVu/Z3JhcGguZ2l0aHVi/YXNzZXRzLmNvbS8x/MjJmYzE0NzE4NzFk/M2UwYTM3YmJhZTZl/MjIxZWJlM2Y4ZGJh/OTQ5MzgwNGMyNDNl/NDJjZjYzYzBjM2Fi/MjMwL2p1cHl0ZXIv/bm90ZWJvb2s",
#           "original": "https://opengraph.githubassets.com/122fc1471871d3e0a37bbae6e221ebe3f8dba9493804c243e42cf63c0c3ab230/jupyter/notebook"
#         },
#         "age": "May 3, 2021",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "The Jupyter Notebook \u2014 Jupyter Notebook 7.3.2 documentation",
#         "url": "https://jupyter-notebook.readthedocs.io/en/stable/notebook.html",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Built on the power of the computational notebook format, <strong>Jupyter</strong> Notebook offers fast, interactive new ways to prototype and explain your code, explore and visualize your data, and share your ideas with others.",
#         "page_age": "2023-06-02T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "Readthedocs",
#           "long_name": "jupyter-notebook.readthedocs.io",
#           "url": "https://jupyter-notebook.readthedocs.io/en/stable/notebook.html",
#           "img": "https://imgs.search.brave.com/u7JXOaPTss7lTIDXUR-yjYf2WgvKgNd-FWzADfb47fs/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMzhmMzA4Y2Jk/N2Y3OTkwYzEwM2Ri/YzhhMjM3NTQ1Zjcz/NTczZTM4ZjNjOTJi/MGQ3MDZkYzNjYjRk/Zjg1NTk2Ny9qdXB5/dGVyLW5vdGVib29r/LnJlYWR0aGVkb2Nz/LmlvLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "jupyter-notebook.readthedocs.io",
#           "hostname": "jupyter-notebook.readthedocs.io",
#           "favicon": "https://imgs.search.brave.com/u7JXOaPTss7lTIDXUR-yjYf2WgvKgNd-FWzADfb47fs/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMzhmMzA4Y2Jk/N2Y3OTkwYzEwM2Ri/YzhhMjM3NTQ1Zjcz/NTczZTM4ZjNjOTJi/MGQ3MDZkYzNjYjRk/Zjg1NTk2Ny9qdXB5/dGVyLW5vdGVib29r/LnJlYWR0aGVkb2Nz/LmlvLw",
#           "path": "\u203a en  \u203a stable  \u203a notebook.html"
#         },
#         "thumbnail": null,
#         "age": "June 2, 2023",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "colab.google",
#         "url": "https://colab.google/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Colab is a hosted <strong>Jupyter</strong> Notebook service that requires no setup to use and provides free access to computing resources, including GPUs and TPUs.",
#         "page_age": null,
#         "page_fetched": null,
#         "profile": {
#           "name": "Colab",
#           "long_name": "colab.google",
#           "url": "https://colab.google/",
#           "img": "https://imgs.search.brave.com/nPGs1rlO1-L-E34McRwXekavbiELyoGFOIDWI_ZrDMA/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNDc0ZWIzMGVj/ZWQwMDkyMWEyMDZh/NWU3OWY0OGE1NTNl/ODQ5Mzk5YjA0NTc3/ZDE4MWZkNTYxNDBm/Zjk3Njk3ZS9jb2xh/Yi5nb29nbGUv"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "colab.google",
#           "hostname": "colab.google",
#           "favicon": "https://imgs.search.brave.com/nPGs1rlO1-L-E34McRwXekavbiELyoGFOIDWI_ZrDMA/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNDc0ZWIzMGVj/ZWQwMDkyMWEyMDZh/NWU3OWY0OGE1NTNl/ODQ5Mzk5YjA0NTc3/ZDE4MWZkNTYxNDBm/Zjk3Njk3ZS9jb2xh/Yi5nb29nbGUv",
#           "path": ""
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/4HXHXrp0gIZnjMduBy2BA1BBD8fRuu-UL6k-5TDltlQ/rs:fit:200:200:1:0/g:ce/aHR0cDovLzAuMC4w/LjA6ODA4MC9zdGF0/aWMvaW1hZ2VzL3No/YXJlLnBuZw",
#           "original": "http://0.0.0.0:8080/static/images/share.png"
#         },
#         "age": null,
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "Working with Jupyter Notebooks in Visual Studio Code",
#         "url": "https://code.visualstudio.com/docs/datascience/jupyter-notebooks",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Working with <strong>Jupyter</strong> Notebooks in Visual Studio Code.",
#         "page_age": "2023-09-04T09:50:04",
#         "page_fetched": null,
#         "profile": {
#           "name": "Visualstudio",
#           "long_name": "code.visualstudio.com",
#           "url": "https://code.visualstudio.com/docs/datascience/jupyter-notebooks",
#           "img": "https://imgs.search.brave.com/Ss8On-q_OmE9m3HK81vWCxjsSiBf3GQKVNyv-aR6BQs/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvM2Q1MjIwOWMx/Yjk0OTY2NjgyOGVk/MGJlNDQ2YTFjZGQy/ODNkNjI3ZTg0MTc3/MzU1NGE1N2ZjMzMz/ZWEyNTE5OS9jb2Rl/LnZpc3VhbHN0dWRp/by5jb20v"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "code.visualstudio.com",
#           "hostname": "code.visualstudio.com",
#           "favicon": "https://imgs.search.brave.com/Ss8On-q_OmE9m3HK81vWCxjsSiBf3GQKVNyv-aR6BQs/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvM2Q1MjIwOWMx/Yjk0OTY2NjgyOGVk/MGJlNDQ2YTFjZGQy/ODNkNjI3ZTg0MTc3/MzU1NGE1N2ZjMzMz/ZWEyNTE5OS9jb2Rl/LnZpc3VhbHN0dWRp/by5jb20v",
#           "path": "\u203a docs  \u203a datascience  \u203a jupyter-notebooks"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/wzSsNwEMenq1aT4X0iVC4zhwp67u4p8nG8-2MZQfzCI/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9jb2Rl/LnZpc3VhbHN0dWRp/by5jb20vYXNzZXRz/L2RvY3MvZGF0YXNj/aWVuY2UvdHV0b3Jp/YWwvcHl0aG9uLXNv/Y2lhbC5wbmc",
#           "original": "https://code.visualstudio.com/assets/docs/datascience/tutorial/python-social.png"
#         },
#         "age": "September 4, 2023",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "How to Install Jupyter Notebook on Windows - GeeksforGeeks",
#         "url": "https://www.geeksforgeeks.org/install-jupyter-notebook-in-windows/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "<strong>Jupyter</strong> Notebook can be installed on Windows using various methods including Anaconda, pip, Microsoft Store, and Miniconda, each catering to different user preferences and system requirements.",
#         "page_age": "2024-12-20T11:35:05",
#         "page_fetched": null,
#         "profile": {
#           "name": "GeeksforGeeks",
#           "long_name": "geeksforgeeks.org",
#           "url": "https://www.geeksforgeeks.org/install-jupyter-notebook-in-windows/",
#           "img": "https://imgs.search.brave.com/bGE5KD5Za34la_MeOAt7584d1aXRWEQopsXEQyAALPw/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYjBhOGQ3MmNi/ZWE5N2EwMmZjYzA1/ZTI0ZTFhMGUyMTE0/MGM0ZTBmMWZlM2Y2/Yzk2ODMxZTRhYTBi/NDdjYTE0OS93d3cu/Z2Vla3Nmb3JnZWVr/cy5vcmcv"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "faq",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "geeksforgeeks.org",
#           "hostname": "www.geeksforgeeks.org",
#           "favicon": "https://imgs.search.brave.com/bGE5KD5Za34la_MeOAt7584d1aXRWEQopsXEQyAALPw/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYjBhOGQ3MmNi/ZWE5N2EwMmZjYzA1/ZTI0ZTFhMGUyMTE0/MGM0ZTBmMWZlM2Y2/Yzk2ODMxZTRhYTBi/NDdjYTE0OS93d3cu/Z2Vla3Nmb3JnZWVr/cy5vcmcv",
#           "path": "\u203a install-jupyter-notebook-in-windows"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/RM5kcfh-L5JKhjWHw8Ud3sg6pGFZl2FddTYkRMtaTMY/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9tZWRp/YS5nZWVrc2Zvcmdl/ZWtzLm9yZy93cC1j/b250ZW50L3VwbG9h/ZHMvMjAyMDAxMjAx/NzA4MTQvSnVweXRl/ci1JbnN0YWxsYXRp/b24tMDEuanBn",
#           "original": "https://media.geeksforgeeks.org/wp-content/uploads/20200120170814/Jupyter-Installation-01.jpg"
#         },
#         "age": "2 weeks ago",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "How to Use Jupyter Notebook in 2024: A Beginner\u2019s Tutorial",
#         "url": "https://www.dataquest.io/blog/jupyter-notebook-tutorial/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Learn how to create your first <strong>Jupyter</strong> Notebook, important terminology, and how easily notebooks can be shared and published online.",
#         "page_age": "2024-08-21T21:43:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "Dataquest",
#           "long_name": "dataquest.io",
#           "url": "https://www.dataquest.io/blog/jupyter-notebook-tutorial/",
#           "img": "https://imgs.search.brave.com/U_PPT9vbZBzt8VU21YJyWZcfEQv0m-xVNiv573_1XYM/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZmFhOTc1NzUy/ZmIwZDc1MWM2YTcw/ZmE1ZDIzYjMyNDg5/MTFlMjk3YjE0YmFh/MjE4MzRhMzk2NTlh/MTFmNzM5Zi93d3cu/ZGF0YXF1ZXN0Lmlv/Lw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "article",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "dataquest.io",
#           "hostname": "www.dataquest.io",
#           "favicon": "https://imgs.search.brave.com/U_PPT9vbZBzt8VU21YJyWZcfEQv0m-xVNiv573_1XYM/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZmFhOTc1NzUy/ZmIwZDc1MWM2YTcw/ZmE1ZDIzYjMyNDg5/MTFlMjk3YjE0YmFh/MjE4MzRhMzk2NTlh/MTFmNzM5Zi93d3cu/ZGF0YXF1ZXN0Lmlv/Lw",
#           "path": "\u203a blog  \u203a jupyter-notebook-tutorial"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/GDMmwEzBMI3MOFltzNV8h0k_C3wTG272ThlZ7GQcrpY/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly93d3cu/ZGF0YXF1ZXN0Lmlv/L3dwLWNvbnRlbnQv/dXBsb2Fkcy8yMDI0/LzA1L2p1cHl0ZXIt/bm90ZWJvb2stdHV0/b3JpYWwucG5n",
#           "original": "https://www.dataquest.io/wp-content/uploads/2024/05/jupyter-notebook-tutorial.png"
#         },
#         "age": "August 21, 2024",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "GitHub - jupyter/docker-stacks: Ready-to-run Docker images containing Jupyter applications",
#         "url": "https://github.com/jupyter/docker-stacks",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "<strong>Jupyter</strong> Docker Stacks are a set of ready-to-run Docker images containing <strong>Jupyter</strong> applications and interactive computing tools.",
#         "page_age": "2023-04-06T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "GitHub",
#           "long_name": "github.com",
#           "url": "https://github.com/jupyter/docker-stacks",
#           "img": "https://imgs.search.brave.com/xxsA4YxzaR0cl-DBsH9-lpv2gsif3KMYgM87p26bs_o/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWQyNWM1NjA5/ZjZmZjNlYzI2MDNk/N2VkNmJhYjE2MzZl/MDY5ZTMxMDUzZmY1/NmU3NWIzNWVmMjk0/NTBjMjJjZi9naXRo/dWIuY29tLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "software",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "github.com",
#           "hostname": "github.com",
#           "favicon": "https://imgs.search.brave.com/xxsA4YxzaR0cl-DBsH9-lpv2gsif3KMYgM87p26bs_o/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWQyNWM1NjA5/ZjZmZjNlYzI2MDNk/N2VkNmJhYjE2MzZl/MDY5ZTMxMDUzZmY1/NmU3NWIzNWVmMjk0/NTBjMjJjZi9naXRo/dWIuY29tLw",
#           "path": "\u203a jupyter  \u203a docker-stacks"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/lhFU-g2PthE2Yj4JpTYRRrzsE41UA6fIifmkIUBSeO8/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9vcGVu/Z3JhcGguZ2l0aHVi/YXNzZXRzLmNvbS9l/ZDQ4N2QyY2E0YjJl/M2Y4Njg0YzNkYTA3/MWI5MDVmMjMyM2Qw/ZjY0NmMwNmQyZTM4/ZGVlNzcyMDJlNzU1/OWFiL2p1cHl0ZXIv/ZG9ja2VyLXN0YWNr/cw",
#           "original": "https://opengraph.githubassets.com/ed487d2ca4b2e3f8684c3da071b905f2323d0f646c06d2e38dee77202e7559ab/jupyter/docker-stacks"
#         },
#         "age": "April 6, 2023",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "Jupyter at ACCRE | ACCRE | Vanderbilt University",
#         "url": "https://www.vanderbilt.edu/accre/jupyter/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "<strong>Jupyter</strong> notebooks have become a widely used data analysis platform in the last several years, primarily in academic research and data science. Notebooks provide programmers with the ability to combine code, documentation, analysis, and visualization inside a single document that is accessible ...",
#         "page_age": null,
#         "page_fetched": null,
#         "profile": {
#           "name": "Vanderbilt",
#           "long_name": "vanderbilt.edu",
#           "url": "https://www.vanderbilt.edu/accre/jupyter/",
# ...
#           "path": "\u203a accre  \u203a jupyter"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/Djy7xFbBL8hplEORGDeIAVOEQO5RmqDs0dSHhaPYTpo/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9uZXdz/LnZhbmRlcmJpbHQu/ZWR1L2ZpbGVzL3Zh/bmRlcmJpbHQtZ2Vu/ZXJpYy1nb2xkLmpw/Zw",
#           "original": "https://news.vanderbilt.edu/files/vanderbilt-generic-gold.jpg"
#         },
#         "age": null,
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "Google Colab",
#         "url": "https://colab.research.google.com/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "Search the world&#x27;s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you&#x27;re looking for.",
#         "page_age": "2021-09-27T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "Google",
#           "long_name": "colab.research.google.com",
#           "url": "https://colab.research.google.com/",
#           "img": "https://imgs.search.brave.com/AdqPsBzu-p7XSxGIpJOEgGFZcEqKPNNG_lHLIl8CkwM/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMmE2NGNkNDBk/ODYxNTZhMTYzYzhl/NGE1ZmJjZGJhMjQ0/ZTZhZWM0OWY3MGNl/YzI2N2Q0MmZiNDk3/NGIyMDliNS9jb2xh/Yi5yZXNlYXJjaC5n/b29nbGUuY29tLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "colab.research.google.com",
#           "hostname": "colab.research.google.com",
#           "favicon": "https://imgs.search.brave.com/AdqPsBzu-p7XSxGIpJOEgGFZcEqKPNNG_lHLIl8CkwM/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMmE2NGNkNDBk/ODYxNTZhMTYzYzhl/NGE1ZmJjZGJhMjQ0/ZTZhZWM0OWY3MGNl/YzI2N2Q0MmZiNDk3/NGIyMDliNS9jb2xh/Yi5yZXNlYXJjaC5n/b29nbGUuY29tLw",
#           "path": ""
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/5jWb2qMt8ovomRbFfQoD0HJFrYNViK2EO84KtcKlRHY/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9jb2xh/Yi5yZXNlYXJjaC5n/b29nbGUuY29tL2lt/Zy9jb2xhYl9mYXZp/Y29uXzI1NnB4LnBu/Zw",
#           "original": "https://colab.research.google.com/img/colab_favicon_256px.png"
#         },
#         "age": "September 27, 2021",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "Jupyter Notebook Documentation \u2014 Jupyter Notebook 7.4.0a0 documentation",
#         "url": "https://jupyter-notebook.readthedocs.io/en/latest/index.html",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "<strong>Jupyter</strong> Notebook is a simplified notebook authoring application, and is a part of Project <strong>Jupyter</strong>, a large umbrella project centered around the goal of providing tools (and standards) for interactive computing with computational notebooks.",
#         "page_age": "2023-05-17T13:50:02",
#         "page_fetched": null,
#         "profile": {
#           "name": "Readthedocs",
#           "long_name": "jupyter-notebook.readthedocs.io",
#           "url": "https://jupyter-notebook.readthedocs.io/en/latest/index.html",
#           "img": "https://imgs.search.brave.com/u7JXOaPTss7lTIDXUR-yjYf2WgvKgNd-FWzADfb47fs/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMzhmMzA4Y2Jk/N2Y3OTkwYzEwM2Ri/YzhhMjM3NTQ1Zjcz/NTczZTM4ZjNjOTJi/MGQ3MDZkYzNjYjRk/Zjg1NTk2Ny9qdXB5/dGVyLW5vdGVib29r/LnJlYWR0aGVkb2Nz/LmlvLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "jupyter-notebook.readthedocs.io",
#           "hostname": "jupyter-notebook.readthedocs.io",
#           "favicon": "https://imgs.search.brave.com/u7JXOaPTss7lTIDXUR-yjYf2WgvKgNd-FWzADfb47fs/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMzhmMzA4Y2Jk/N2Y3OTkwYzEwM2Ri/YzhhMjM3NTQ1Zjcz/NTczZTM4ZjNjOTJi/MGQ3MDZkYzNjYjRk/Zjg1NTk2Ny9qdXB5/dGVyLW5vdGVib29r/LnJlYWR0aGVkb2Nz/LmlvLw",
#           "path": "\u203a en  \u203a latest  \u203a index.html"
#         },
#         "thumbnail": null,
#         "age": "May 17, 2023",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "GitHub - jupyter/jupyter_client: Jupyter protocol client APIs",
#         "url": "https://github.com/jupyter/jupyter_client",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "<strong>Jupyter</strong> protocol client APIs. Contribute to <strong>jupyter</strong>/<strong>jupyter</strong>_client development by creating an account on GitHub.",
#         "page_age": "2022-07-25T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "GitHub",
#           "long_name": "github.com",
#           "url": "https://github.com/jupyter/jupyter_client",
#           "img": "https://imgs.search.brave.com/xxsA4YxzaR0cl-DBsH9-lpv2gsif3KMYgM87p26bs_o/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWQyNWM1NjA5/ZjZmZjNlYzI2MDNk/N2VkNmJhYjE2MzZl/MDY5ZTMxMDUzZmY1/NmU3NWIzNWVmMjk0/NTBjMjJjZi9naXRo/dWIuY29tLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "software",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "github.com",
#           "hostname": "github.com",
#           "favicon": "https://imgs.search.brave.com/xxsA4YxzaR0cl-DBsH9-lpv2gsif3KMYgM87p26bs_o/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWQyNWM1NjA5/ZjZmZjNlYzI2MDNk/N2VkNmJhYjE2MzZl/MDY5ZTMxMDUzZmY1/NmU3NWIzNWVmMjk0/NTBjMjJjZi9naXRo/dWIuY29tLw",
#           "path": "\u203a jupyter  \u203a jupyter_client"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/NxlOv4z578ihvlRUWk8iajkcFfwzdAobaXdHkVsjayQ/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9vcGVu/Z3JhcGguZ2l0aHVi/YXNzZXRzLmNvbS85/YWM3YzlmY2ZjMmNl/NjY5MDE0MmRkZjNk/ZGNmM2Q2MWY4YzY3/ZTNmYjc3M2QyMjhk/NTZhNDkwZGY0MjAy/NzU0L2p1cHl0ZXIv/anVweXRlcl9jbGll/bnQ",
#           "original": "https://opengraph.githubassets.com/9ac7c9fcfc2ce6690142ddf3ddcf3d61f8c67e3fb773d228d56a490df4202754/jupyter/jupyter_client"
#         },
#         "age": "July 25, 2022",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "JupyterLab Documentation \u2014 JupyterLab 4.4.0a1 ...",
#         "url": "https://jupyterlab.readthedocs.io/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "JupyterLab is a highly extensible, feature-rich notebook authoring application and editing environment, and is a part of Project <strong>Jupyter</strong>, a large umbrella project centered around the goal of providing tools (and standards) for interactive computing with computational notebooks.",
#         "page_age": "2020-04-13T00:00:00",
#         "page_fetched": null,
#         "profile": {
#           "name": "Readthedocs",
#           "long_name": "jupyterlab.readthedocs.io",
#           "url": "https://jupyterlab.readthedocs.io/",
#           "img": "https://imgs.search.brave.com/E5Cmfd7QbakMV2WaPpasOdFyNl6Qt80mbuwz1MXiL6g/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNTBkMjU5OTU1/MDNhOTY4OWZkM2Yx/N2ZmNjM3ZWI5MGRj/Yjc4N2NlYzM0YWQ5/YWM4OTI0MzhjZDU1/M2VjOTg0My9qdXB5/dGVybGFiLnJlYWR0/aGVkb2NzLmlvLw"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "jupyterlab.readthedocs.io",
#           "hostname": "jupyterlab.readthedocs.io",
#           "favicon": "https://imgs.search.brave.com/E5Cmfd7QbakMV2WaPpasOdFyNl6Qt80mbuwz1MXiL6g/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNTBkMjU5OTU1/MDNhOTY4OWZkM2Yx/N2ZmNjM3ZWI5MGRj/Yjc4N2NlYzM0YWQ5/YWM4OTI0MzhjZDU1/M2VjOTg0My9qdXB5/dGVybGFiLnJlYWR0/aGVkb2NzLmlvLw",
#           "path": ""
#         },
#         "thumbnail": null,
#         "age": "April 13, 2020",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "r/Jupyter",
#         "url": "https://www.reddit.com/r/Jupyter/",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "I&#x27;ve spent over a day just trying to get past this setup stage. As someone who usually works with pure Python, I feel like I&#x27;m missing something fundamental about how Python packages interact with JupyterLab&#x27;s extension system.",
#         "page_age": "2014-07-10T15:26:57",
#         "page_fetched": null,
#         "profile": {
#           "name": "Reddit",
#           "long_name": "reddit.com",
#           "url": "https://www.reddit.com/r/Jupyter/",
#           "img": "https://imgs.search.brave.com/U-eHNCapRHVNWWCVPPMTIvOofZULh0_A_FQKe8xTE4I/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvN2ZiNTU0M2Nj/MTFhZjRiYWViZDlk/MjJiMjBjMzFjMDRk/Y2IzYWI0MGI0MjVk/OGY5NzQzOGQ5NzQ5/NWJhMWI0NC93d3cu/cmVkZGl0LmNvbS8"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "generic",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "reddit.com",
#           "hostname": "www.reddit.com",
#           "favicon": "https://imgs.search.brave.com/U-eHNCapRHVNWWCVPPMTIvOofZULh0_A_FQKe8xTE4I/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvN2ZiNTU0M2Nj/MTFhZjRiYWViZDlk/MjJiMjBjMzFjMDRk/Y2IzYWI0MGI0MjVk/OGY5NzQzOGQ5NzQ5/NWJhMWI0NC93d3cu/cmVkZGl0LmNvbS8",
#           "path": "\u203a r  \u203a Jupyter"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/BnN38CzI3uztA__1TlmRILnejqq8mmBnf60SfApxbrI/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly93d3cu/cmVkZGl0c3RhdGlj/LmNvbS9zaHJlZGRp/dC9hc3NldHMvZmF2/aWNvbi8xOTJ4MTky/LnBuZw",
#           "original": "https://www.redditstatic.com/shreddit/assets/favicon/192x192.png"
#         },
#         "age": "July 10, 2014",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       },
#       {
#         "title": "How to Install Jupyter Notebook in Windows 11 - 2024 - YouTube",
#         "url": "https://www.youtube.com/watch?v=fMra3jyTHkQ",
#         "is_source_local": false,
#         "is_source_both": false,
#         "description": "In the lecture I will show you how to install <strong>jupyter</strong> notebook in windows 11 or how to install <strong>jupyter</strong> notebook in windows 10.I will explain how to download ...",
#         "page_age": "2024-07-26T16:10:29",
#         "page_fetched": null,
#         "profile": {
#           "name": "YouTube",
#           "long_name": "youtube.com",
#           "url": "https://www.youtube.com/watch?v=fMra3jyTHkQ",
#           "img": "https://imgs.search.brave.com/Wg4wjE5SHAargkzePU3eSLmWgVz84BEZk1SjSglJK_U/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvOTkyZTZiMWU3/YzU3Nzc5YjExYzUy/N2VhZTIxOWNlYjM5/ZGVjN2MyZDY4Nzdh/ZDYzMTYxNmI5N2Rk/Y2Q3N2FkNy93d3cu/eW91dHViZS5jb20v"
#         },
#         "language": "en",
#         "family_friendly": true,
#         "type": "search_result",
#         "subtype": "video",
#         "is_live": false,
#         "deep_results": null,
#         "schemas": null,
#         "meta_url": {
#           "scheme": "https",
#           "netloc": "youtube.com",
#           "hostname": "www.youtube.com",
#           "favicon": "https://imgs.search.brave.com/Wg4wjE5SHAargkzePU3eSLmWgVz84BEZk1SjSglJK_U/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvOTkyZTZiMWU3/YzU3Nzc5YjExYzUy/N2VhZTIxOWNlYjM5/ZGVjN2MyZDY4Nzdh/ZDYzMTYxNmI5N2Rk/Y2Q3N2FkNy93d3cu/eW91dHViZS5jb20v",
#           "path": "  \u203a saad qureshi official"
#         },
#         "thumbnail": {
#           "src": "https://imgs.search.brave.com/ZEYSZn3m784gt2Ag1Fd_fQXjmu-11wFKaEo9V7wzdng/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly9pLnl0/aW1nLmNvbS92aS9m/TXJhM2p5VEhrUS9t/YXhyZXNkZWZhdWx0/LmpwZw",
#           "original": "https://i.ytimg.com/vi/fMra3jyTHkQ/maxresdefault.jpg"
#         },
#         "age": "July 26, 2024",
#         "location": null,
#         "video": null,
#         "movie": null,
#         "faq": null,
#         "qa": null,
#         "book": null,
#         "rating": null,
#         "article": null,
#         "product": null,
#         "product_cluster": null,
#         "cluster_type": null,
#         "cluster": null,
#         "creative_work": null,
#         "music_recording": null,
#         "review": null,
#         "software": null,
#         "recipe": null,
#         "organization": null,
#         "content_type": null,
#         "extra_snippets": null
#       }
#     ],
#     "family_friendly": true
#   },
#   "summarizer": null
# }
