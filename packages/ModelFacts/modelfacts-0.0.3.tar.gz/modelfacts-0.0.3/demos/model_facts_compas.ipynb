# %% [markdown]
# # Model Facts Example: COMPAS
# This notebook provides an example of how to generate a Model Facts from the results of the COMPAS analysis completed by ProPublica exposing bias in the COMPAS recidivism risk analysis model.
#
# We will focus on the violent recidivism model and dataset.
#
# The results are published in this news article: https://www.propublica.org/article/machine-bias-risk-assessments-in-criminal-sentencing
#
# The data used is available here: https://github.com/propublica/compas-analysis/tree/master
#
# As an example of the impact of undefined and non-transparent definitions of fairness and bias, Northpointe (creators of COMPAS) has their rebuttal available here: https://go.volarisgroup.com/rs/430-MBX-989/images/ProPublica_Commentary_Final_070616.pdf
#
# Contents are as follows:
# 0. Setup
# 1. Data Processing
# 2. *Create Model Facts Label*
# 3. Compare the impact of other scoring measures

# %% [markdown]
# ## 0. Setup
# - Download the `cox-violent-parsed.csv` dataset from https://github.com/propublica/compas-analysis/tree/master
# - Load packages and data
#
# Columns of interest are:
# - `v_score_text`: The COMPAS model score label (Low, Medium, High) from their violent recidivism prediction model
# - `v_decile_score`: The COMPAS quantitative score (1-10)
# - `is_violent_recid`: Whether or not they commited a new violent crime within two years after release (0 = not a recidivist)
# - `priors_count`: The number of prior crimes. For the sake of this example, we will use this as a baseline for comparison

# %%
import pandas as pd
import datetime as dt
from sklearn import metrics

from modelfacts import  ModelFacts

# %%
data = pd.read_csv('../data/compas/cox-violent-parsed.csv')
data.shape
# Out:
# (18316, 52)

# %% [markdown]
# ## 1. Data Preprocessing
# - Filter out bad data:
#     - Some of the data is missing scores or have start dates before end dates, demonstrating potential errors in the data. This is in line with the Propublica team's method in https://github.com/propublica/compas-analysis/blob/master/Compas%20Analysis.ipynb
# - Create binary predictions (for accuracy calculations): we label all data with "High" COMPAS labels to be a prediction of violent recidivism. "Medium" and "Low" are set to 0.
#     - The Propublica team labeled High and Medium as 1. However, the Northpointe team took issue with this in their rebuttal
# - Create a baseline prediction: While no baseline model is available, we create our own baseline under the assumption that people with a greater criminal history (`prior_counts`) are more likely to be a violent recidivist.
#     - We establish a threshold to mirror the percentage of violent recidivists in the data.
#     - This baseline should not be used in real life. It propagates the systemic biases caused by racism and overpolicing of Black and Brown neighborhoods.
# - Format data for easy Model Facts label generation

# %%
# filter out unreliable data
data = data[(~data['score_text'].isna()) & (data['end']>data['start'])].copy()
# new data size
len(data)
# Out:
# 18178

# %%
split = {'High': 1, 'Medium':0, 'Low':0}
# create baseline 
# based on priors count 
# the cutoff is the linear quantile of the percent of recidivists
perc_recid = sum(data['is_violent_recid'])/len(data)
cutoff = data['priors_count'].quantile(q=1-perc_recid)
data['baseline_text'] = data['priors_count'].where(data['priors_count']>0, 'Low')\
    .where((data['priors_count']<=0) | (data['priors_count']>cutoff), 'Medium')\
    .where(data['priors_count']<=cutoff, 'High')

data['baseline_proba'] = data['priors_count']
data['baseline'] = data['baseline_text'].replace(split)
data['pred'] = data['v_score_text'].replace(split)
# Out:
# /tmp/ipykernel_230520/2574884248.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['baseline'] = data['baseline_text'].replace(split)
# /tmp/ipykernel_230520/2574884248.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['pred'] = data['v_score_text'].replace(split)

# %% [markdown]
# ## 2. Create Model Facts Label
# Generate the label using this data
# - The Standard Score is the F1-score as this is an imbalanced classification problem
# - The Training Score is AUC, as noted in Northpointe's paper: https://journals.sagepub.com/doi/abs/10.1177/0093854808326545
# - There is clearly a large discrepancy between African-Americans and Caucasian's accuracy, with the former's F-1 being almost 2x higher. While one may usually want higher scores, in real life context this discrepancy has resulted in African-American defendants being more negatively impacted than Caucasian defendants, continuing the cycle of systemic racism in the criminal justice system.

# %%
# set admin details
application = "Predicting risk of violent recidivism using COMPAS. " \
"The target class is predicting violent recidivism"
model_type = "classification"
warnings = "This model has been demonstrated to propagate biases by ProPublica." \
 " Its creators claim this model is unbiased, under the predictive parity paradigm using AUC." \
 " Without a clear definition of fairness, it should not be used in decision making"
source = "Data from Broward County, Florida https://github.com/propublica/compas-analysis/tree/master." \
" Model created by Northpointe"
train_date = max(pd.to_datetime(data['compas_screening_date'])) # date compas model was used
test_data_date = dt.datetime(2016,5,23) # propublica article publication
data_split = "NA/100"
data_size = len(data)
true_col = "is_violent_recid"
pred_col = "pred"
baseline_col = "baseline"
pred_proba = "v_decile_score"
baseline_proba = "baseline_proba"
age_col = "age" # which column has age information in it
demo_cols = ['race', 'sex', 'age'] # which columns has additional demographic information in it
# define scoring functions
st_score = 'f1_score'
st_kwargs = {} # e.g. {'average':'macro'} any of the keyword arguments for the score of interest
t_score = 'roc_auc_score'
t_kwargs = {} # same usage as st kwargs
t_score_func = getattr(metrics, t_score)
st_score_func = getattr(metrics, st_score)

# %%
# create model facts object
model_facts = ModelFacts(data, true_col, pred_col, baseline_col, 
                         st_score_func, t_score_func, classification = True, 
                         pred_proba = pred_proba, baseline_proba = baseline_proba,
                         t_proba = True)
# calculate various stats along demographics
mf_compas = model_facts(demo_cols, age_col = age_col,
    train_date = train_date, test_data_date = test_data_date,
    data_size = data_size, data_split = data_split,
    st_kwargs = st_kwargs, t_kwargs = t_kwargs)
# create the Model Facts label from the data
table = model_facts.make_label(mf_compas, application, warnings, source, show = True)
# Out:
# <div id="xpzxeccpiu" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #xpzxeccpiu table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #xpzxeccpiu thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #xpzxeccpiu p { margin: 0; padding: 0; }
#  #xpzxeccpiu .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #xpzxeccpiu .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #xpzxeccpiu .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #xpzxeccpiu .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #xpzxeccpiu .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #xpzxeccpiu .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #xpzxeccpiu .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #xpzxeccpiu .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #xpzxeccpiu .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #xpzxeccpiu .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #xpzxeccpiu .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #xpzxeccpiu .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #xpzxeccpiu .gt_spanner_row { border-bottom-style: hidden; }
#  #xpzxeccpiu .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #xpzxeccpiu .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #xpzxeccpiu .gt_from_md> :first-child { margin-top: 0; }
#  #xpzxeccpiu .gt_from_md> :last-child { margin-bottom: 0; }
#  #xpzxeccpiu .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #xpzxeccpiu .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #xpzxeccpiu .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #xpzxeccpiu .gt_row_group_first td { border-top-width: 2px; }
#  #xpzxeccpiu .gt_row_group_first th { border-top-width: 2px; }
#  #xpzxeccpiu .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #xpzxeccpiu .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #xpzxeccpiu .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #xpzxeccpiu .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #xpzxeccpiu .gt_left { text-align: left; }
#  #xpzxeccpiu .gt_center { text-align: center; }
#  #xpzxeccpiu .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #xpzxeccpiu .gt_font_normal { font-weight: normal; }
#  #xpzxeccpiu .gt_font_bold { font-weight: bold; }
#  #xpzxeccpiu .gt_font_italic { font-style: italic; }
#  #xpzxeccpiu .gt_super { font-size: 65%; }
#  #xpzxeccpiu .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #xpzxeccpiu .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Model Facts</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Application: Predicting risk of violent recidivism using COMPAS. The target class is predicting violent recidivism</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr class="gt_empty_group_heading">
#     <th class="gt_group_heading" colspan="4" style="color: Black;font-weight: bold;"></th>
#   </tr>
#   <tr>
#     <th class="gt_row gt_left gt_stub">Model Type</th>
#     <td class="gt_

# %%
table.save('model_facts_compas.png', web_driver = "firefox", window_size = (640,360));

# %% [markdown]
# ## 3. Comparison
# As demonstrated in Northpointe's rebuttal, the scoring metric you use can be quite effective in masking biases.
#
# We recreate a Model Facts label using AUC to calculate demographic statistics.

# %%
# all other variables stay the same
t_score = 'f1_score'
st_score = 'roc_auc_score'
st_proba = True
t_proba = False
t_score_func = getattr(metrics, t_score)
st_score_func = getattr(metrics, st_score)

# create model facts object
model_facts = ModelFacts(data, true_col, pred_col, baseline_col, 
                         st_score_func, t_score_func, classification = True, 
                         pred_proba = pred_proba, baseline_proba = baseline_proba,
                         st_proba = st_proba, t_proba = t_proba)
# calculate various stats along demographics
mf_compas_auc= model_facts(demo_cols, age_col = age_col,
    train_date = train_date, test_data_date = test_data_date,
    data_size = data_size, data_split = data_split,
    st_kwargs = st_kwargs, t_kwargs = t_kwargs)
# create the Model Facts label from the data
table = model_facts.make_label(mf_compas_auc, application, warnings, source, show = True)
# Out:
# <div id="dqsnlwswmp" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #dqsnlwswmp table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #dqsnlwswmp thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #dqsnlwswmp p { margin: 0; padding: 0; }
#  #dqsnlwswmp .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #dqsnlwswmp .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #dqsnlwswmp .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #dqsnlwswmp .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #dqsnlwswmp .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dqsnlwswmp .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #dqsnlwswmp .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dqsnlwswmp .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #dqsnlwswmp .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #dqsnlwswmp .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #dqsnlwswmp .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #dqsnlwswmp .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #dqsnlwswmp .gt_spanner_row { border-bottom-style: hidden; }
#  #dqsnlwswmp .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #dqsnlwswmp .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #dqsnlwswmp .gt_from_md> :first-child { margin-top: 0; }
#  #dqsnlwswmp .gt_from_md> :last-child { margin-bottom: 0; }
#  #dqsnlwswmp .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #dqsnlwswmp .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #dqsnlwswmp .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #dqsnlwswmp .gt_row_group_first td { border-top-width: 2px; }
#  #dqsnlwswmp .gt_row_group_first th { border-top-width: 2px; }
#  #dqsnlwswmp .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #dqsnlwswmp .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #dqsnlwswmp .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #dqsnlwswmp .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #dqsnlwswmp .gt_left { text-align: left; }
#  #dqsnlwswmp .gt_center { text-align: center; }
#  #dqsnlwswmp .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #dqsnlwswmp .gt_font_normal { font-weight: normal; }
#  #dqsnlwswmp .gt_font_bold { font-weight: bold; }
#  #dqsnlwswmp .gt_font_italic { font-style: italic; }
#  #dqsnlwswmp .gt_super { font-size: 65%; }
#  #dqsnlwswmp .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #dqsnlwswmp .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Model Facts</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Application: Predicting risk of violent recidivism using COMPAS. The target class is predicting violent recidivism</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr class="gt_empty_group_heading">
#     <th class="gt_group_heading" colspan="4" style="color: Black;font-weight: bold;"></th>
#   </tr>
#   <tr>
#     <th class="gt_row gt_left gt_stub">Model Type</th>
#     <td class="gt_

# %%
table.save('model_facts_compas_auc.png', web_driver = "firefox", window_size = (640,360));

# %%
# all other variables stay the same
t_score = 'f1_score'
st_score = 'precision_score'
st_proba = False
t_proba = False
t_score_func = getattr(metrics, t_score)
st_score_func = getattr(metrics, st_score)

# create model facts object
model_facts = ModelFacts(data, true_col, pred_col, baseline_col, 
                         st_score_func, t_score_func, classification = True, 
                         pred_proba = pred_proba, baseline_proba = baseline_proba,
                         st_proba = st_proba, t_proba = t_proba)
# calculate various stats along demographics
mf_compas_ppv= model_facts(demo_cols, age_col = age_col,
    train_date = train_date, test_data_date = test_data_date,
    data_size = data_size, data_split = data_split,
    st_kwargs = st_kwargs, t_kwargs = t_kwargs)
# create the Model Facts label from the data
table = model_facts.make_label(mf_compas_ppv, application, warnings, source, show = True)
# Out:
# /home/jzhu/umd/model_facts/.model_facts/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# <div id="ygyyvwklmu" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ygyyvwklmu table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ygyyvwklmu thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ygyyvwklmu p { margin: 0; padding: 0; }
#  #ygyyvwklmu .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ygyyvwklmu .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ygyyvwklmu .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #ygyyvwklmu .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #ygyyvwklmu .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ygyyvwklmu .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ygyyvwklmu .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ygyyvwklmu .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ygyyvwklmu .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ygyyvwklmu .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ygyyvwklmu .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ygyyvwklmu .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ygyyvwklmu .gt_spanner_row { border-bottom-style: hidden; }
#  #ygyyvwklmu .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ygyyvwklmu .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ygyyvwklmu .gt_from_md> :first-child { margin-top: 0; }
#  #ygyyvwklmu .gt_from_md> :last-child { margin-bottom: 0; }
#  #ygyyvwklmu .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ygyyvwklmu .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ygyyvwklmu .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ygyyvwklmu .gt_row_group_first td { border-top-width: 2px; }
#  #ygyyvwklmu .gt_row_group_first th { border-top-width: 2px; }
#  #ygyyvwklmu .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #ygyyvwklmu .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ygyyvwklmu .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ygyyvwklmu .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ygyyvwklmu .gt_left { text-align: left; }
#  #ygyyvwklmu .gt_center { text-align: center; }
#  #ygyyvwklmu .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ygyyvwklmu .gt_font_normal { font-weight: normal; }
#  #ygyyvwklmu .gt_font_bold { font-weight: bold; }
#  #ygyyvwklmu .gt_font_italic { font-style: italic; }
#  #ygyyvwklmu .gt_super { font-size: 65%; }
#  #ygyyvwklmu .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ygyyvwklmu .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Model Facts</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Application: Predicting risk of violent recidivism using COMPAS. The target class is predicting violent recidivism</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr class="gt_empty_group_heading">
#     <th class="gt_group_heading" colspan="4" style="color: Black;font-weight: bold;"></th>
#   </tr>
#   <tr>
#     <th class="gt_row gt_left gt_stub">Model Type</th>
#     <td class="gt_

# %%
table.save('model_facts_compas_ppv.png', web_driver = "firefox", window_size = (640,360));
