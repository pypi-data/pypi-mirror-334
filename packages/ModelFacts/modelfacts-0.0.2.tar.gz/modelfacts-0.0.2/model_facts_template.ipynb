# %% [markdown]
# # Model Facts Template
# This notebook will allow you to generate a Model Facts Label by filling out a form.

# %% [markdown]
# Requirements:
# - package installation `pip install modelfacts`
# - Test data in a csv file with demographic information, true lables, predicted labels, and baseline data as `['true', 'pred', 'baseline']`, respectively
# - Knowledge of the various other fields (e.g. data set size, split, dates, scores used)
#
# How to use:
# 1. Click run on the next cell
# 2. Complete the the form
# 3. Run the next cell
# 4. Model Facts label will be generated! (Screenshot to save)

# %%
# 1st run this cell
from modelfacts import ModelFactsWidget
wm = ModelFactsWidget()
wm
# Out:
# ModelFactsWidget(children=(Textarea(value='', description='What is the application of this model?', layout=Lay…

# %%
# Run this cell after completing the form
# Creates the label 
# You can rerun this cell after reselecting values in the widget 
# without restarting the notebook
table = wm.create_label()
# Out:
# /home/jzhu/umd/model_facts/.model_facts/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# <div id="iljwepncyl" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #iljwepncyl table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #iljwepncyl thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #iljwepncyl p { margin: 0; padding: 0; }
#  #iljwepncyl .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #iljwepncyl .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #iljwepncyl .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #iljwepncyl .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #iljwepncyl .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #iljwepncyl .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #iljwepncyl .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #iljwepncyl .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #iljwepncyl .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #iljwepncyl .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #iljwepncyl .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #iljwepncyl .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #iljwepncyl .gt_spanner_row { border-bottom-style: hidden; }
#  #iljwepncyl .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #iljwepncyl .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #iljwepncyl .gt_from_md> :first-child { margin-top: 0; }
#  #iljwepncyl .gt_from_md> :last-child { margin-bottom: 0; }
#  #iljwepncyl .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #iljwepncyl .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #iljwepncyl .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #iljwepncyl .gt_row_group_first td { border-top-width: 2px; }
#  #iljwepncyl .gt_row_group_first th { border-top-width: 2px; }
#  #iljwepncyl .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #iljwepncyl .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #iljwepncyl .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #iljwepncyl .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #iljwepncyl .gt_left { text-align: left; }
#  #iljwepncyl .gt_center { text-align: center; }
#  #iljwepncyl .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #iljwepncyl .gt_font_normal { font-weight: normal; }
#  #iljwepncyl .gt_font_bold { font-weight: bold; }
#  #iljwepncyl .gt_font_italic { font-style: italic; }
#  #iljwepncyl .gt_super { font-size: 65%; }
#  #iljwepncyl .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #iljwepncyl .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Model Facts</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Application: Undefined model application</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr class="gt_empty_group_heading">
#     <th class="gt_group_heading" colspan="4" style="color: Black;font-weight: bold;"></th>
#   </tr>
#   <tr>
#     <th class="gt_row gt_left gt_stub">Model Type</th>
#     <td class="gt_row gt_left">classification</td>
#     <td class="gt_row gt_left"></td>

# %%
table.save('model_facts_template.png', web_driver = "firefox", window_size = (640,360));
